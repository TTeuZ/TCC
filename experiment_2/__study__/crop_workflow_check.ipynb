# %%
import json

# %%
with open("/home/tteuz/Desktop/Datasets/pucpr_spots.json", "r") as file:
    pucpr = json.load(file)

with open("/home/tteuz/Desktop/Datasets/ufpr04_spots.json", "r") as file:
    ufpr04 = json.load(file)

with open("/home/tteuz/Desktop/Datasets/ufpr05_spots.json", "r") as file:
    ufpr05 = json.load(file)

# %%
diff_images = set()

for annotation in pucpr["annotations"]:
    diff_images.add(annotation["image_id"])

diff_images = list(diff_images)
image = pucpr["images"][diff_images[0]]

print(f"images len: {len(pucpr['images'])}")
print(f"ann_images len: {len(diff_images)}")
print(image)
# Out:
# images len: 4474
# ann_images len: 4474
# {'id': 0, 'file_name': 'PUCPR/Sunny/2012-11-20/2012-11-20_08_54_39.jpg', 'width': 1280, 'height': 720, 'date': [2012, 11, 20], 'time': [8, 54, 39], 'climate': 2, 'dataset': 'pklot', 'subset': 'pucpr'}

# %%
diff_images = set()

for annotation in ufpr04["annotations"]:
    diff_images.add(annotation["image_id"])

diff_images = list(diff_images)
image = ufpr04["images"][diff_images[0]]

print(f"images len: {len(ufpr04['images'])}")
print(f"ann_images len: {len(diff_images)}")
print(image)
# Out:
# images len: 3791
# ann_images len: 3791
# {'id': 0, 'file_name': 'UFPR04/Sunny/2012-12-07/2012-12-07_20_17_28.jpg', 'width': 1280, 'height': 720, 'annotationsRectangle': [0, 0, 1280, 720], 'date': [2012, 12, 7], 'time': [20, 17, 28], 'climate': 2, 'dataset': 'pklot', 'subset': 'ufpr04'}

# %%
diff_images = set()

for annotation in ufpr05["annotations"]:
    diff_images.add(annotation["image_id"])

diff_images = list(diff_images)
image = ufpr05["images"][diff_images[0]]

print(f"images len: {len(ufpr05['images'])}")
print(f"ann_images len: {len(diff_images)}")
print(image)
# Out:
# images len: 4135
# ann_images len: 4135
# {'id': 0, 'file_name': 'UFPR05/Cloudy/2013-02-22/2013-02-22_18_10_13.jpg', 'width': 1280, 'height': 720, 'annotationsRectangle': [0, 0, 1280, 720], 'date': [2013, 2, 22], 'time': [18, 10, 13], 'climate': 3, 'dataset': 'pklot', 'subset': 'ufpr05'}

# %% [markdown]
# ------------------------------------

# %%
diff_images = set()

for annotation in pucpr["annotations"]:
    diff_images.add(annotation["image_id"])

pucpr_dict = {image: [] for image in diff_images}

for annotation in pucpr["annotations"]:
    pucpr_dict[annotation["image_id"]].append(annotation)

print(len(pucpr_dict))
print(len(pucpr_dict[0]))
print(pucpr_dict[0])
# Out:
# 4474
# 195
# ...
