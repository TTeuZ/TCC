# %%
import json

# %%
with open("/home/tteuz/Desktop/Datasets/annotation_information_pucpr_spots.json", "r") as file:
    pucpr = json.load(file)

with open("/home/tteuz/Desktop/Datasets/annotation_information_ufpr04_spots.json", "r") as file:
    ufpr04 = json.load(file)

with open("/home/tteuz/Desktop/Datasets/annotation_information_ufpr05_spots.json", "r") as file:
    ufpr05 = json.load(file)

# %%
print(f"puc keys: {len(pucpr.keys())}")
print(f"ufpr04 keys: {len(ufpr04.keys())}")
print(f"ufpr05 keys: {len(ufpr05.keys())}")
# Out:
# puc keys: 872430
# ufpr04 keys: 137217
# ufpr05 keys: 190210

# %%
print(f"puc keys: {len(list(pucpr.keys()))}")
# Out:
# puc keys: 872430

# %%
temp = list(pucpr.values())
print(temp[1000])
# Out:
# {'embedding_indexes': {'pklot_2024_01_20_15_50_17_siamese_08-0.0304.hdf5': {'index': 5103}, 'cnr_2024_01_21_16_08_14_siamese_47-0.0136.hdf5': {'index': 5103}, 'pklot_2024_01_20_18_53_24_siamese_18-0.0344.hdf5': {'index': 5103}, 'cnr_2024_01_21_18_49_55_siamese_29-0.0124.hdf5': {'index': 5103}, 'cnr_2024_01_21_21_35_12_siamese_41-0.0133.hdf5': {'index': 5103}, 'cnr_2024_01_22_00_19_57_siamese_48-0.0154.hdf5': {'index': 5103}, 'cnr_2024_01_22_03_08_33_siamese_38-0.0112.hdf5': {'index': 5103}}, 'classification_predictions': {'cnr_2024_01_20_02_57_37_best_model.pt': {'category': 1}, 'cnr_2024_01_20_03_17_44_best_model.pt': {'category': 1}, 'cnr_2024_01_20_03_37_33_best_model.pt': {'category': 1}, 'cnr_2024_01_20_03_57_12_best_model.pt': {'category': 1}, 'cnr_2024_01_20_04_16_30_best_model.pt': {'category': 1}}, 'spot_id': 84}
