# %%
import json

# %%
with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-1_spots.json", "r") as file:
    cam1 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-2_spots.json", "r") as file:
    cam2 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-3_spots.json", "r") as file:
    cam3 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-4_spots.json", "r") as file:
    cam4 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-5_spots.json", "r") as file:
    cam5 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-6_spots.json", "r") as file:
    cam6 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-7_spots.json", "r") as file:
    cam7 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-8_spots.json", "r") as file:
    cam8 = json.load(file)

with open("/home/tteuz/Desktop/TCC/datasets/PKLot2.0/CNRPark-EXT/cnr-camera-9_spots.json", "r") as file:
    cam9 = json.load(file)

# %%
print(f"cam 1 keys: {cam1.keys()}")
print(f"cam 2 keys: {cam2.keys()}")
print(f"cam 3 keys: {cam3.keys()}")
print(f"cam 4 keys: {cam4.keys()}")
print(f"cam 5 keys: {cam5.keys()}")
print(f"cam 6 keys: {cam6.keys()}")
print(f"cam 7 keys: {cam7.keys()}")
print(f"cam 8 keys: {cam8.keys()}")
print(f"cam 9 keys: {cam9.keys()}")
# Out:
# cam 1 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 2 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 3 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 4 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 5 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 6 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 7 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 8 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])
# cam 9 keys: dict_keys(['categories', 'climates', 'images', 'annotations'])

# %%
print(cam1["categories"])
print(cam2["categories"])
print(cam3["categories"])
print(cam4["categories"])
print(cam5["categories"])
print(cam6["categories"])
print(cam7["categories"])
print(cam8["categories"])
print(cam9["categories"])
# Out:
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]
# [{'id': 0, 'name': 'empty'}, {'id': 1, 'name': 'occupied'}]

# %%
print(cam1["climates"])
print(cam2["climates"])
print(cam3["climates"])
print(cam4["climates"])
print(cam5["climates"])
print(cam6["climates"])
print(cam7["climates"])
print(cam8["climates"])
print(cam9["climates"])
# Out:
# [{'id': 1, 'name': 'overcast'}, {'id': 2, 'name': 'sunny'}, {'id': 3, 'name': 'rainy'}, {'id': 4, 'name': 'snowy'}, {'id': 5, 'name': 'no_rain '}, {'id': 6, 'name': 'undefined'}]
# [{'id': 1, 'name': 'overcast'}, {'id': 2, 'name': 'sunny'}, {'id': 3, 'name': 'rainy'}, {'id': 4, 'name': 'snowy'}, {'id': 5, 'name': 'no_rain '}, {'id': 6, 'name': 'undefined'}]
# [{'id': 1, 'name': 'overcast'}, {'id': 2, 'name': 'sunny'}, {'id': 3, 'name': 'rainy'}, {'id': 4, 'name': 'snowy'}, {'id': 5, 'name': 'no_rain '}, {'id': 6, 'name': 'undefined'}]
# [{'id': 1, 'name': 'overcast'}, {'id': 2, 'name': 'sunny'}, {'id': 3, 'name': 'rainy'}, {'id': 4, 'name': 'snowy'}, {'id': 5, 'name': 'no_rain '}, {'id': 6, 'name': 'undefined'}]
# [{'id': 1, 'name': 'overcast'}, {'id': 2, 'name': 'sunny'}, {'id': 3, 'name': 'rainy'}, {'id': 4, 'name': 'snowy'}, {'id': 5, 'name': 'no_rain '}, {'id': 6, 'name': 'undefined'}]
# ...

# %%
print(cam1["images"][0])
print(cam2["images"][0])
print(cam3["images"][0])
print(cam4["images"][0])
print(cam5["images"][0])
print(cam6["images"][0])
print(cam7["images"][0])
print(cam8["images"][0])
print(cam9["images"][0])
# Out:
# {'id': 0, 'file_name': 'OVERCAST/2015-12-19/camera1/2015-12-19_1048.jpg', 'width': 1000, 'height': 750, 'annotationsRectangle': [115, 140, 1000, 750], 'date': [2015, 12, 19], 'time': [10, 48], 'climate': 1, 'dataset': 'cnr', 'subset': 'camera1'}
# {'id': 0, 'file_name': 'OVERCAST/2015-12-19/camera2/2015-12-19_0817.jpg', 'width': 1000, 'height': 750, 'annotationsRectangle': [0, 0, 1000, 750], 'date': [2015, 12, 19], 'time': [8, 17], 'climate': 1, 'dataset': 'cnr', 'subset': 'camera2'}
# {'id': 0, 'file_name': 'OVERCAST/2015-12-19/camera3/2015-12-19_1048.jpg', 'width': 1000, 'height': 750, 'annotationsRectangle': [0, 0, 1000, 750], 'date': [2015, 12, 19], 'time': [10, 48], 'climate': 1, 'dataset': 'cnr', 'subset': 'camera3'}
# {'id': 0, 'file_name': 'OVERCAST/2015-12-19/camera4/2015-12-19_1021.jpg', 'width': 1000, 'height': 750, 'annotationsRectangle': [0, 0, 1000, 750], 'date': [2015, 12, 19], 'time': [10, 21], 'climate': 1, 'dataset': 'cnr', 'subset': 'camera4'}
# ...

# %%
print(len(cam1["annotations"]))
print(len(cam2["annotations"]))
print(len(cam3["annotations"]))
print(len(cam4["annotations"]))
print(len(cam5["annotations"]))
print(len(cam6["annotations"]))
print(len(cam7["annotations"]))
print(len(cam8["annotations"]))
print(len(cam9["annotations"]))
# Out:
# 17901
# 4640
# 10580
# 17823
# 22752
# 23760
# 22770
# 26620
# 14370

# %%
print(cam1["annotations"][0])
print(cam2["annotations"][0])
print(cam3["annotations"][0])
print(cam4["annotations"][0])
print(cam5["annotations"][0])
print(cam6["annotations"][0])
print(cam7["annotations"][0])
print(cam8["annotations"][0])
print(cam9["annotations"][0])
# Out:
# {'id': 21473, 'image_id': 0, 'category_id': 0, 'segmentation': [[450, 748, 552, 715, 407, 586, 334, 632]], 'iscrowd': 0, 'bbox': [334, 586, 218, 162], 'area': 15874, 'car_id': -1}
# {'id': 4805, 'image_id': 0, 'category_id': 0, 'segmentation': [[3, 626, 284, 673, 339, 540, 3, 479]], 'iscrowd': 0, 'bbox': [3, 479, 336, 194], 'area': 44675, 'car_id': -1}
# {'id': 8151, 'image_id': 0, 'category_id': 0, 'segmentation': [[998, 707, 707, 747, 668, 610, 996, 564]], 'iscrowd': 0, 'bbox': [668, 564, 330, 183], 'area': 44212, 'car_id': -1}
# {'id': 11019, 'image_id': 0, 'category_id': 0, 'segmentation': [[997, 664, 690, 653, 705, 748, 998, 748]], 'iscrowd': 0, 'bbox': [690, 653, 308, 95], 'area': 26806, 'car_id': -1}
# {'id': 13502, 'image_id': 0, 'category_id': 0, 'segmentation': [[128, 749, 489, 746, 494, 654, 183, 632]], 'iscrowd': 0, 'bbox': [128, 632, 366, 117], 'area': 35397, 'car_id': -1}
# ...
