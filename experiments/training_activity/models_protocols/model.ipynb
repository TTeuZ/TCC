# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np

import knn
import metrics

# %% [markdown]
# ### Getting the train and test sets

# %%
df_train = pd.read_csv("../features/train.csv")
df_test = pd.read_csv("../features/test.csv")

# %% [markdown]
# ### Data normalization

# %%
train_y = np.array(df_train.filter(["256"], axis=1))
train_x = np.array(df_train.drop(["dataset", "weather", "date", "hour", "parking_space", "256"], axis=1))

test_y = np.array(df_test.filter(["256"], axis=1))
test_x = np.array(df_test.drop(["dataset", "weather", "date", "hour", "parking_space", "256"], axis=1))

# %%
scaler = MinMaxScaler()
scaler.fit(train_x)

normed_train = scaler.transform(train_x)
normed_test = scaler.transform(test_x)

# %% [markdown]
# ### Model fit and prediction

# %%
model = knn.KNearestNeighbors()
model.fit(normed_train, train_y)

preds = model.predict(normed_test)

# %% [markdown]
# ### Metrics

# %%
print(f"Accuracy: {metrics.accuracy_score(test_y, preds)}")
print("----------------------------------------------------------------------")

print("Confusion matrix:")
cm = metrics.confusion_matrix(test_y, preds)
for i in reversed(range(2)):
    for j in reversed(range(2)):
        print(cm[i][j], end=' ')
    print('\n', end='')
print("----------------------------------------------------------------------")
# Out:
# Accuracy: 0.87
# ----------------------------------------------------------------------
# Confusion matrix:
# 12649 3104
# 1487 19177
# ----------------------------------------------------------------------

# %% [markdown]
# ### Metrics with sklearn

# %%
print(f"Accuracy: {accuracy_score(test_y, preds)}")
print("----------------------------------------------------------------------")

print("Confusion matrix:")
cm = confusion_matrix(test_y, preds)
for i in reversed(range(2)):
    for j in reversed(range(2)):
        print(cm[i][j], end=' ')
    print('\n', end='')
print("----------------------------------------------------------------------")

print("Classification report:")
print(classification_report(test_y, preds))
# Out:
# Accuracy: 0.8739325040503062
# ----------------------------------------------------------------------
# Confusion matrix:
# 12649 3104
# 1487 19177
# ----------------------------------------------------------------------
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89     20664
#            1       0.89      0.80      0.85     15753
#
#     accuracy                           0.87     36417
#    macro avg       0.88      0.87      0.87     36417
# weighted avg       0.88      0.87      0.87     36417
